# %% [markdown]
# ## 1.Kiểu số int - float - int() - float()

# %%
int(3.14)
# Out:
# 3

# %%
float(3.14)
# Out:
# 3.14

# %% [markdown]
# ## 2. Kiểu chuỗi -str - str()

# %%
#+         0123456789 11
ho_ten = ('Phan Trung Kien')

# %%
#-         -12        -1
ho_ten1 = ('Lmao Kien')

# %% [markdown]
# ### Tìm hiểu quy tắc PEP8 trong khai báo biến, hàm

# %%
len("hahaha")
# Out:
# 6

# %% [markdown]
# ## 3. Kiểu danh sách - list - list()

# %% [markdown]
# ### Kiểu list cho phép lưu trữ nhiều giá trị

# %%
#index + 0     1                2
sv =   [123, 'Phan Trung Kiên', 8.8]
#index - -3   -2               -1

# %%
sv = [
    123,
    'Phan Trung Kiên',
    8.8
]

# %%
type(sv)
# Out:
# list

# %%
sv
# Out:
# [123, 'Phan Trung Kiên', 8.8]

# %%
sv[-2]
# Out:
# 'Phan Trung Kiên'

# %%
sv[1]
# Out:
# 'Phan Trung Kiên'

# %%
len([])
# Out:
# 0

# %% [markdown]
# ## 4. Kiểu tuple - tuple - tuple()

# %%
# Kiểu tuple dùng để lưu trữ nhiều giá trị, nhưng ko cho phép thay đổi

# %%
#index+  0          1            2
sv1 = (123, 'Phan Trung Kien', 8.8)

# %%
#index- -3         -2          -1
sv2 = 123, 'Phan Trung Kiên', 8.8

# %%
type(sv1)
# Out:
# tuple

# %%
#Tuple 1 phần tử
sv3 = 123,

# %%
type(sv3)
# Out:
# tuple

# %%
# Tìm hiểu thêm các hàm có sẵn dùng được, các phương thức liên quan .name.function()

# %% [markdown]
# ## 5. Kiểu từ điển - dict - dict()

# %%
# key : value

# %%
sv = {
'ma_sv': 123,
'ho_ten': 'Phan Trung Kien',
'diem': 8.8
}

# %%
sv
# Out:
# {'ma_sv': 123, 'ho_ten': 'Phan Trung Kien', 'diem': 8.8}

# %%
# Lấy giá trị, cập nhật, thêm mới

# %%
sv['ma_sv'] = 789

# %%
sv
# Out:
# {'ma_sv': 789, 'ho_ten': 'Phan Trung Kien', 'diem': 8.8}

# %%
sv['drl'] = 100

# %%
sv
# Out:
# {'ma_sv': 789, 'ho_ten': 'Phan Trung Kien', 'diem': 8.8, 'drl': 100}

# %%
# bool,    số      , str, list, tuple, dict, set    , none
True   #   khác 0       ko rỗng
False #      0       rỗng                             none
# Out:
# False

# %% [markdown]
# ## 6. Kiểu tập hợp - set - set()

# %%
# Kiểu set dùng để lưu trữ nhiều giá trị, ko có index, key, chỉ có giá trị

# %%
{4, 9 , 'Python', 8.3, 9.0}
# Out:
# {4, 8.3, 9, 'Python'}

# %% [markdown]
# ## 7. Kiểu boolean - bool - bool()

# %%
x = True
y = False

# %%
tinh_trang_tn = False

# %%
ds = [2, 7, 4, 9, 6, 'f', 'd']

# %%
6 in ds
# Out:
# True

# %%
6.2 in ds
# Out:
# False

# %%
7 not in ds
# Out:
# False

# %% [markdown]
# ## 8. Giá trị None

# %%
# None là giá trị đặc biệt, đại diện cho chưa có giá trị

# %%
so_kg = None
